# %% [markdown]
# # FileDrop Installation Test
#
# This notebook tests that the filedrop package was installed correctly.

# %%
# Test import
from jupyter_iframe_upload import FileDrop, IFrameDropWidget
print('Import successful!')

# %%
# Test FileDrop widget
fd = FileDrop("Test Data").display()

# %%
# After dropping a file, access the DataFrame:
df = fd["Test Data"]
if df is not None:
    print(f"Loaded: {df.shape}")
    display(df.head())
else:
    print("No file loaded yet - drop a CSV/XLSX file above!")

# %%
# Test multiple drop zones
fd2 = FileDrop("Train", "Test").display()

# %%
# Test dynamic add/remove
fd2.add("Validation")
